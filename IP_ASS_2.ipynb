# %% [markdown]
# <a href="https://colab.research.google.com/github/SHRESHTH121/Demo/blob/main/IP_ASS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
img = cv2.imread('/content/RGB image.jpg')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
print("Original Image")
cv2_imshow(img)
# Out:
# Original Image
# <PIL.Image.Image image mode=RGB size=1280x853>

# %%
print("Grayscale Image")
cv2_imshow(gray)
# Out:
# Grayscale Image
# <PIL.Image.Image image mode=L size=1280x853>

# %%
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
R = rgb[:, :, 0]
G = rgb[:, :, 1]
B = rgb[:, :, 2]

# %%
gray = (0.299 * R + 0.587 * G + 0.114 * B).astype(np.uint8)

# %%
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=1280x853>

# %%
gray = np.mean(rgb, axis=2).astype(np.uint8)

# %%
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=1280x853>
